# %% [markdown]
# # Use the inbuilt dataset 'titanic'. The dataset contains 891 rows and contains information about the passengers who boarded the unfortunate Titanic ship. Use the Seaborn library to see if we can find any patterns in the data. 2. Write a code to check how the price of the ticket (column name: 'fare') for each passenger is distributed by plotting a histogram. how to solve above assignment#

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df= sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
print(df.head())
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
print(df.tail())
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB
# None

# %%
print(df.shape)
# Out:
# (891, 15)

# %%
sns.jointplot(x='fare',y='age',data=df)

# %%
#Step 3: Explore Patterns in the Data Using Seaborn#
sns.countplot(x='survived', data=df)
plt.title("Survival Count")
plt.show()

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
#Sactter Plot -To check Outliers in the data-In above graph, we can observe the outliers of column 'Fare'
#with respect to the column 'Age'.
sns.scatterplot(data=df,x='age',y='fare')
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
#In Seaborn, hue is a parameter used to add color grouping to a plot based on a categorical variable.
#Simple meaning:
#hue separates data using different colors.In  graph, we can observe the outliers of column 'Fare' with respect to the
#column 'Age'.  As hue is 'Gender' it is also segregated w.r.t to gender.

sns.scatterplot(data=df,x='age',y='fare',hue='sex')
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
sns.countplot(x='survived',hue='embark_town',data=df)
#For above graph, survival of people town wise.
#It is town wise count.
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
sns.catplot(x='embarked',hue='survived',data=df,kind='count')
#a figure-level function used to visualize relationships between numerical and categorical variables by plotting data on a FacetGrid.
#X-axis (embarked): Displays the different ports of embarkation (typically 'C' = Cherbourg, 'Q' = Queenstown, 'S' = Southampton).
#Hue (survived): Colors the bars to differentiate between passengers who died (usually 0) and those who survived (usually 1).
#Y-axis (Count): Indicates the total number of passengers in each combination of port and survival status.
#kind='count': Tells catplot to use the countplot function to count the occurrences of each category rather than plotting a numerical average.

# %%
sns.catplot(x='embarked',hue='survived',data=df,kind='count',col='pclass')

# %%
sns.scatterplot(data=df,x='age',y='fare',hue='pclass')
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
#Histplot
#Histograms are visualization tools that represent the distribution of a set of continuous data.
 #In a histogram,the data is divided into a set of intervals or bins (usually on the x-axis) and the count of data points
 #that fall into each bin corresponding to the height of the bar above that bin.
 #These bins may or may not be equal in width but are adjacent (with no gaps).
#sns.histplot(data=df,x='age')   -Inference: Histplot is used for continuos data.
# graph gives count per age group.
sns.histplot(data=df,x='age')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.histplot(data=df,x='fare')
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
sns.displot(data=df,x='age',bins=10)

# %%
sns.displot(data=df,x='age',bins=60)

# %%
sns.displot(data=df,x='age',hue='sex',bins=30)

# %%
sns.displot(data=df,x='age',hue='sex',bins=30,col='embark_town')
#Southampton (First Graph) , #Maximum passengers boarded from Southampton. , #Most passengers were between 20–40 years.
#More males than females. #Few children and elderly passengers. #Southampton had the highest number of young adult passengers, mostly male.

#Cherbourg (Second Graph) , #Fewer passengers compared to Southampton. , #Age mostly between 20–35 years.
#Gender distribution looks more balanced. , #Some older passengers also present. ,#Cherbourg had moderate number of
#passengers with balanced male-female ratio.

#Queenstown (Third Graph)
#Very few passengers boarded here.Age distribution is scattered.Mostly adults. Very small sample size. Queenstown had the least passengers.

# %%
sns.barplot(x='age',y='fare', data=df)
#Average fare paid by passengers of that age
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
sns.barplot(x='pclass',y='embark_town',data=df,orient='h')
#-pclass and town wise relation ship
# Out:
# <Axes: xlabel='pclass', ylabel='embark_town'>

# %%
sns.barplot(x='pclass',y='embark_town',data=df,orient='v')
# Out:
# <Axes: xlabel='pclass', ylabel='embark_town'>

# %%
#Count Plot- #The count plot is similar to the bar plot, however it displays the count of
#the categories in a specific column. For instance, if we want to count the number of males and women
#passenger we can do so using count plot as follows:
sns.countplot(x='pclass',hue='sex',data=df)
# Out:
# <Axes: xlabel='pclass', ylabel='count'>

# %%
sns.countplot(x='pclass',hue='embark_town',data=df)
#sns.countplot(x='pclass',hue='survived’',data=df)  -We can observe that people from pclass 1 have survived more then pclass 3 Death of pclass 3 people is more
#sns.countplot(x='survived',hue='embark_town',data=df)
# Out:
# <Axes: xlabel='pclass', ylabel='count'>

# %%
#sns.countplot(x='pclass',hue='survived’, data=df)
#We can observe that people from pclass 1 have survived more then pclass 3 Death of pclass 3 people is more
sns.countplot(x='survived',hue='embark_town',data=df)
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
#Observations
#Female passengers had a significantly higher survival rate than male passengers.
#This confirms the historical “women and children first” policy followed during the Titanic disaster.


sns.countplot(x='sex', hue='survived', data=df)
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Gender and Survival Count')
plt.legend(title='Survived', loc='upper right', labels=['No', 'Yes'])
plt.show()

# %%
#Plot Histogram for Fare Column

plt.figure(figsize=(8,5))
sns.histplot(df['fare'], bins=30, kde=True)
plt.title("Distribution of Ticket Fare")
plt.xlabel("Fare")
plt.ylabel("Number of Passengers")
plt.show()

# %%
#Comparing Survival Rates with a Violin Plot
#A violin plot combines KDE and box plots to show distribution differences.
# Comparing Survival Rates with a Violin Plot
#Analysis
#First-class passengers had a higher survival rate, indicated by the wider upper region in the violin plot.
#Third-class passengers had a lower survival rate, with a significant portion of younger passengers.
sns.violinplot(x='survived', y='age', data=df, hue='sex',split=True)
plt.xlabel('Survived')
plt.ylabel('Age')
plt.title('Survival Rates by Age and Gender')
plt.show()

# %%
sns.violinplot(x='survived', y='age', data=df, hue='sex')
plt.xlabel('Survived')
plt.ylabel('Age')
plt.title('Survival Rates by Age and Gender')
plt.show()

# %%
#Analyzing Trends with a Line Plot
#A line plot is useful for time series or sequential data analysis. Here, we plot age against survival rates per class.
# Analyzing Trends with a Line Plot
sns.lineplot(x="age", y="fare", hue="pclass", data=df)
plt.xlabel('Age')
plt.ylabel('Fare')
plt.title('Age vs. Fare by Passenger Class')
plt.show()
#Insights
#The survival rate fluctuates across different ages.
#First-class passengers generally had higher survival rates across all ages.

# %%
sns.swarmplot(x='sex',y='age',data=df, hue='sex')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.swarmplot(x='survived',y='age',data=df, hue='sex')
# Out:
# <Axes: xlabel='survived', ylabel='age'>
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 5.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(x='pclass',y='age',data=df)
# Out:
# <Axes: xlabel='pclass', ylabel='age'>
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 15.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
corr = df.corr(numeric_only=True)
sns.heatmap(corr, annot=True, cmap="Blues", linewidths=0.5)
plt.show()

# %% [markdown]
# Seaborn provides an intuitive way to visualize and analyze datasets effectively. Using the Titanic dataset, we explored:
# Pairplots for understanding relationships between numerical variables.
# Heatmaps for visualizing correlations.
# Histograms and KDE plots for analyzing distributions.
# Box plots and violin plots for comparing categories.
# Bar plots and scatter plots for categorical and numerical analysis.
# Line plots for understanding trends.
